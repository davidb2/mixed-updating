# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import networkx as nx

import moran
from pathlib import Path
from utils import yield_all_graph6

# %%
N = 3
for G in yield_all_graph6(Path(f'./data/connected-n{N}.g6')):
  for r in np.linspace(1, 1.1, 10+1):
    moran.mixed_moran_fix_prob_sys(G, r=r, p_Bd=1/2)
